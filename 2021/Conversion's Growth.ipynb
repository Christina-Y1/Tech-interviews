# %%
import pandas as pd
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# Может ли конверсия в двух источниках снижаться, а общая расти?

# %%
adv_campaign_one = {
    
    'new': [1000, 1000, 1000],
    'converted': [100, 99, 97],
}

df1 = pd.DataFrame(adv_campaign_one)

# %%
df1['conversion'] = df1['converted'] / df1['new']

# %%
df1
# Out:
#     new  converted  conversion
# 0  1000        100       0.100
# 1  1000         99       0.099
# 2  1000         97       0.097

# %%
adv_campaign_two = {
    
    'new_users': [100, 10000, 100000],
    'converted_users': [99, 9800, 96000],
}

df2 = pd.DataFrame(adv_campaign_two)

# %%
df2['conversion'] = df2['converted_users'] / df2['new_users']

# %%
df2
# Out:
#    new_users  converted_users  conversion
# 0        100               99        0.99
# 1      10000             9800        0.98
# 2     100000            96000        0.96

# %%
df_total = pd.concat([df1, df2], axis=1)

# %%
df_total
# Out:
#     new  converted  conversion  new_users  converted_users  conversion
# 0  1000        100       0.100        100               99        0.99
# 1  1000         99       0.099      10000             9800        0.98
# 2  1000         97       0.097     100000            96000        0.96

# %%
df_total[['conversion']]
# Out:
#    conversion  conversion
# 0       0.100        0.99
# 1       0.099        0.98
# 2       0.097        0.96

# %%
df_total['total_users'] = df_total['new_users'] + df_total['new']
df_total['total_converted_users'] = df_total['converted_users'] + df_total['converted']
df_total['total_conversion'] = df_total['total_converted_users'] / df_total['total_users']

# %%
df_total[['conversion', 'total_conversion']]
# Out:
#    conversion  conversion  total_conversion
# 0       0.100        0.99          0.180909
# 1       0.099        0.98          0.899909
# 2       0.097        0.96          0.951455

# %%
plt.plot([0.99, 0.98, 0.96], color= 'c')

plt.show()

# %%
plt.plot([0.1, 0.099, 0.097], color="green", linestyle="dotted")

plt.show()

# %%
plt.plot([0.18, 0.89, 0.95], color="red", linestyle="dashed")

plt.show()
